# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import silhouette_score
from sklearn.cluster import DBSCAN

# %%
ls *.txt
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 9CA7-0D6F
#
#  Directory of C:\Users\pkapo\Documents\DataCamp_2020\Lecture_Python\Asssignments_PythonShapiro\Smiley
#
# 08/05/2020  10:53 AM            94,491 smiley.txt
#                1 File(s)         94,491 bytes
#                0 Dir(s)  328,660,250,624 bytes free

# %%
Data=pd.read_csv("smiley.txt",names=("x","y"))

# %%
Data[:5]
# Out:
#           x         y
# 0  1.142175  5.653880
# 1  0.961976  5.654621
# 2  0.043144  5.031154
# 3  7.976526  2.027480
# 4  6.313825  6.489383

# %%
XY=np.array(Data[["x","y"]])

# %%
plt.scatter(XY[:,0],XY[:,1],s=2)
plt.gcf().set_size_inches(6,6)

# %%
model = DBSCAN(eps=.3, min_samples=5)
model.fit(XY)
for j in np.unique(np.array(model.labels_)):
    if j<0:
        continue
    p,q= XY[model.labels_==j].T
    plt.scatter(p,q,s=10)
plt.gcf().set_size_inches(6,6)
np.unique(model.labels_,return_counts=True)
# Out:
# (array([-1,  0,  1,  2,  3,  4], dtype=int64),
#  array([  14, 3492,  501,  496,  500,  246], dtype=int64))

# %% [markdown]
# # model = DBSCAN(eps=.3, min_samples=5)
# model.fit(XY)
# for j in np.unique(np.array(model.labels_)):
#     #if j<0:
#      #   continue
#     p,q= XY[model.labels_==j].T
#     plt.scatter(p,q,s=10)
# plt.gcf().set_size_inches(6,6)
# np.unique(model.labels_,return_counts=True)

# %%
# Homework - try to cluster smiley.txt using dbscan
# use trial and error to modify eps and num_samples
